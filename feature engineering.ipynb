# %% [markdown]
# Handling Missing Values
# 1 - Impute Missing Values:
# For last_review and reviews_per_month, fill missing values with 0 or the median value.
#
# Encoding Categorical Variables
# 2 - Neighborhood and Room Type:
# One-Hot Encoding: Convert neighbourhood_group, neighbourhood, and room_type into binary columns.
#
# Creating New Features
# 3 - Date Features:
# Extract year, month, and day from last_review.
# 4- Price-Related Features:
# Create a price_per_night by dividing price by minimum_nights.
#
# Spatial Features
# 5 - Geospatial Clustering:
# Apply clustering algorithms (e.g., K-means) on latitude and longitude to identify neighborhood clusters.
#
# Aggregations
# 6 - Review Aggregations:
# Calculate the average number of reviews per month for each neighborhood.
#
# Feature Interactions
# 7 - Price Interaction:
# Create interaction terms like price * number_of_reviews or price / availability_365.
#
# Binning
# 8 - Price Binning:
# Create bins for price to categorize listings into low, medium, and high price ranges.
#
# Scaling and Normalization
# 9 - Standardize Numerical Features:
# Apply standard scaling to price, minimum_nights, number_of_reviews, and availability_365.
#
# Handling Outliers
# 10 - Cap Outliers:
# Cap extreme values in price, minimum_nights, and number_of_reviews.

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.cluster import KMeans
import numpy as np

df = pd.read_csv('AB_NYC_2019.csv')

df['reviews_per_month'].fillna(0, inplace=True)
df['last_review'].fillna('2000-01-01', inplace=True)

# %% [markdown]
# ## One-Hot Encoding

# %%
df = pd.get_dummies(df, columns=['neighbourhood_group', 'neighbourhood', 'room_type'])

# %%
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
#            host_name  latitude  longitude  price  minimum_nights  \
# 0               John  40.64749  -73.97237    149               1
# 1           Jennifer  40.75362  -73.98377    225               1
# 2          Elisabeth  40.80902  -73.94190    150               3
# 3        LisaRoxanne  40.68514  -73.95976     89               1
# 4              Laura  40.79851  -73.94399     80              10
# ...              ...       ...        ...    ...             ...
# 48890        Sabrina  40.67853  -73.94995     70               2
# 48891        Marisol  40.70184  -73.93317     40               4
# 48892  Ilgar & Aysel  40.81475  -73.94867    115              10
# 48893            Taz  40.75751  -73.99112     55               1
# 48894     Christophe  40.76404  -73.98933     90               7
#
#        number_of_reviews last_review  ...  neighbourhood_Williamsburg  \
# 0                      9  2018-10-19  ...                       False
# 1                     45  2019-05-21  ...                       False
# 2                      0  2000-01-01  ...                       False
# 3                    270  2019-07-05  ...                       False
# 4                      9  2018-11-19  ...                       False
# ...                  ...         ...  ...                         ...
# 48890                  0  2000-01-01  ...                       False
# 48891                  0  2000-01-01  ...                       False
# 48892                  0  2000-01-01  ...                       False
# 48893                  0  2000-01-01  ...                       False
# 48894                  0  2000-01-01  ...                       False
#
#        neighbourhood_Willowbrook  neighbourhood_Windsor Terrace  \
# 0                          False                          False
# 1                          False                          False
# 2                          False                          False
# 3                          False                          False
# 4                          False                          False
# ...                          ...                            ...
# 48890                      False                          False
# 48891                      False                          False
# 48892                      False                          False
# 48893                      False                          False
# 48894                      False                          False
#
#        neighbourhood_Woodhaven  neighbourhood_Woodlawn  neighbourhood_Woodrow  \
# 0                        False                   False                  False
# 1                        False                   False                  False
# 2                        False                   False                  False
# 3                        False                   False                  False
# 4                        False                   False                  False
# ...                        ...                     ...                    ...
# 48890                    False                   False                  False
# 48891                    False                   False                  False
# 48892                    False                   False                  False
# 48893                    False                   False                  False
# 48894                    False                   False                  False
#
#        neighbourhood_Woodside  room_type_Entire home/apt  \
# 0                       False                      False
# 1                       False                       True
# 2                       False                      False
# 3                       False                       True
# 4                       False                       True
# ...                       ...                        ...
# 48890                   False                      False
# 48891                   False                      False
# 48892                   False                       True
# 48893                   False                      False
# 48894                   False                      False
#
#        room_type_Private room  room_type_Shared room
# 0                        True                  False
# 1                       False                  False
# 2                        True                  False
# 3                       False                  False
# 4                       False                  False
# ...                       ...                    ...
# 48890                    True                  False
# 48891                    True                  False
# 48892                   False                  False
# 48893                   False                   True
# 48894                    True                  False
#
# [48895 rows x 242 columns]

# %% [markdown]
# ## Date Features

# %%
df['last_review'] = pd.to_datetime(df['last_review'])
df['last_review_year'] = df['last_review'].dt.year
df['last_review_month'] = df['last_review'].dt.month
df['last_review_day'] = df['last_review'].dt.day

# %%
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
#            host_name  latitude  longitude  price  minimum_nights  \
# 0               John  40.64749  -73.97237    149               1
# 1           Jennifer  40.75362  -73.98377    225               1
# 2          Elisabeth  40.80902  -73.94190    150               3
# 3        LisaRoxanne  40.68514  -73.95976     89               1
# 4              Laura  40.79851  -73.94399     80              10
# ...              ...       ...        ...    ...             ...
# 48890        Sabrina  40.67853  -73.94995     70               2
# 48891        Marisol  40.70184  -73.93317     40               4
# 48892  Ilgar & Aysel  40.81475  -73.94867    115              10
# 48893            Taz  40.75751  -73.99112     55               1
# 48894     Christophe  40.76404  -73.98933     90               7
#
#        number_of_reviews last_review  ...  neighbourhood_Woodhaven  \
# 0                      9  2018-10-19  ...                    False
# 1                     45  2019-05-21  ...                    False
# 2                      0  2000-01-01  ...                    False
# 3                    270  2019-07-05  ...                    False
# 4                      9  2018-11-19  ...                    False
# ...                  ...         ...  ...                      ...
# 48890                  0  2000-01-01  ...                    False
# 48891                  0  2000-01-01  ...                    False
# 48892                  0  2000-01-01  ...                    False
# 48893                  0  2000-01-01  ...                    False
# 48894                  0  2000-01-01  ...                    False
#
#        neighbourhood_Woodlawn  neighbourhood_Woodrow  neighbourhood_Woodside  \
# 0                       False                  False                   False
# 1                       False                  False                   False
# 2                       False                  False                   False
# 3                       False                  False                   False
# 4                       False                  False                   False
# ...                       ...                    ...                     ...
# 48890                   False                  False                   False
# 48891                   False                  False                   False
# 48892                   False                  False                   False
# 48893                   False                  False                   False
# 48894                   False                  False                   False
#
#        room_type_Entire home/apt  room_type_Private room  \
# 0                          False                    True
# 1                           True                   False
# 2                          False                    True
# 3                           True                   False
# 4                           True                   False
# ...                          ...                     ...
# 48890                      False                    True
# 48891                      False                    True
# 48892                       True                   False
# 48893                      False                   False
# 48894                      False                    True
#
#        room_type_Shared room  last_review_year  last_review_month  \
# 0                      False              2018                 10
# 1                      False              2019                  5
# 2                      False              2000                  1
# 3                      False              2019                  7
# 4                      False              2018                 11
# ...                      ...               ...                ...
# 48890                  False              2000                  1
# 48891                  False              2000                  1
# 48892                  False              2000                  1
# 48893                   True              2000                  1
# 48894                  False              2000                  1
#
#        last_review_day
# 0                   19
# 1                   21
# 2                    1
# 3                    5
# 4                   19
# ...                ...
# 48890                1
# 48891                1
# 48892                1
# 48893                1
# 48894                1
#
# [48895 rows x 245 columns]

# %% [markdown]
# ## Price-Related Features

# %%
df['price_per_night'] = df['price'] / df['minimum_nights']

# %%
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
#            host_name  latitude  longitude  price  minimum_nights  \
# 0               John  40.64749  -73.97237    149               1
# 1           Jennifer  40.75362  -73.98377    225               1
# 2          Elisabeth  40.80902  -73.94190    150               3
# 3        LisaRoxanne  40.68514  -73.95976     89               1
# 4              Laura  40.79851  -73.94399     80              10
# ...              ...       ...        ...    ...             ...
# 48890        Sabrina  40.67853  -73.94995     70               2
# 48891        Marisol  40.70184  -73.93317     40               4
# 48892  Ilgar & Aysel  40.81475  -73.94867    115              10
# 48893            Taz  40.75751  -73.99112     55               1
# 48894     Christophe  40.76404  -73.98933     90               7
#
#        number_of_reviews last_review  ...  neighbourhood_Woodlawn  \
# 0                      9  2018-10-19  ...                   False
# 1                     45  2019-05-21  ...                   False
# 2                      0  2000-01-01  ...                   False
# 3                    270  2019-07-05  ...                   False
# 4                      9  2018-11-19  ...                   False
# ...                  ...         ...  ...                     ...
# 48890                  0  2000-01-01  ...                   False
# 48891                  0  2000-01-01  ...                   False
# 48892                  0  2000-01-01  ...                   False
# 48893                  0  2000-01-01  ...                   False
# 48894                  0  2000-01-01  ...                   False
#
#        neighbourhood_Woodrow  neighbourhood_Woodside  \
# 0                      False                   False
# 1                      False                   False
# 2                      False                   False
# 3                      False                   False
# 4                      False                   False
# ...                      ...                     ...
# 48890                  False                   False
# 48891                  False                   False
# 48892                  False                   False
# 48893                  False                   False
# 48894                  False                   False
#
#        room_type_Entire home/apt  room_type_Private room  \
# 0                          False                    True
# 1                           True                   False
# 2                          False                    True
# 3                           True                   False
# 4                           True                   False
# ...                          ...                     ...
# 48890                      False                    True
# 48891                      False                    True
# 48892                       True                   False
# 48893                      False                   False
# 48894                      False                    True
#
#        room_type_Shared room  last_review_year  last_review_month  \
# 0                      False              2018                 10
# 1                      False              2019                  5
# 2                      False              2000                  1
# 3                      False              2019                  7
# 4                      False              2018                 11
# ...                      ...               ...                ...
# 48890                  False              2000                  1
# 48891                  False              2000                  1
# 48892                  False              2000                  1
# 48893                   True              2000                  1
# 48894                  False              2000                  1
#
#        last_review_day  price_per_night
# 0                   19       149.000000
# 1                   21       225.000000
# 2                    1        50.000000
# 3                    5        89.000000
# 4                   19         8.000000
# ...                ...              ...
# 48890                1        35.000000
# 48891                1        10.000000
# 48892                1        11.500000
# 48893                1        55.000000
# 48894                1        12.857143
#
# [48895 rows x 246 columns]

# %% [markdown]
# ## Price Interaction

# %%
df['price_num_reviews'] = df['price'] * df['number_of_reviews']
df['price_availability'] = df['price'] / (df['availability_365'] + 1)

# %%
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
#            host_name  latitude  longitude  price  minimum_nights  \
# 0               John  40.64749  -73.97237    149               1
# 1           Jennifer  40.75362  -73.98377    225               1
# 2          Elisabeth  40.80902  -73.94190    150               3
# 3        LisaRoxanne  40.68514  -73.95976     89               1
# 4              Laura  40.79851  -73.94399     80              10
# ...              ...       ...        ...    ...             ...
# 48890        Sabrina  40.67853  -73.94995     70               2
# 48891        Marisol  40.70184  -73.93317     40               4
# 48892  Ilgar & Aysel  40.81475  -73.94867    115              10
# 48893            Taz  40.75751  -73.99112     55               1
# 48894     Christophe  40.76404  -73.98933     90               7
#
#        number_of_reviews last_review  ...  neighbourhood_Woodside  \
# 0                      9  2018-10-19  ...                   False
# 1                     45  2019-05-21  ...                   False
# 2                      0  2000-01-01  ...                   False
# 3                    270  2019-07-05  ...                   False
# 4                      9  2018-11-19  ...                   False
# ...                  ...         ...  ...                     ...
# 48890                  0  2000-01-01  ...                   False
# 48891                  0  2000-01-01  ...                   False
# 48892                  0  2000-01-01  ...                   False
# 48893                  0  2000-01-01  ...                   False
# 48894                  0  2000-01-01  ...                   False
#
#        room_type_Entire home/apt  room_type_Private room  \
# 0                          False                    True
# 1                           True                   False
# 2                          False                    True
# 3                           True                   False
# 4                           True                   False
# ...                          ...                     ...
# 48890                      False                    True
# 48891                      False                    True
# 48892                       True                   False
# 48893                      False                   False
# 48894                      False                    True
#
#        room_type_Shared room  last_review_year  last_review_month  \
# 0                      False              2018                 10
# 1                      False              2019                  5
# 2                      False              2000                  1
# 3                      False              2019                  7
# 4                      False              2018                 11
# ...                      ...               ...                ...
# 48890                  False              2000                  1
# 48891                  False              2000                  1
# 48892                  False              2000                  1
# 48893                   True              2000                  1
# 48894                  False              2000                  1
#
#        last_review_day  price_per_night  price_num_reviews  price_availability
# 0                   19       149.000000               1341            0.407104
# 1                   21       225.000000              10125            0.632022
# 2                    1        50.000000                  0            0.409836
# 3                    5        89.000000              24030            0.456410
# 4                   19         8.000000                720           80.000000
# ...                ...              ...                ...                 ...
# 48890                1        35.000000                  0            7.000000
# 48891                1        10.000000                  0            1.081081
# 48892                1        11.500000                  0            4.107143
# 48893                1        55.000000                  0           18.333333
# 48894                1        12.857143                  0            3.750000
#
# [48895 rows x 248 columns]

# %% [markdown]
# ## Binning

# %%
df['price_bin'] = pd.cut(df['price'], bins=[0, 50, 100, 200, np.inf], labels=['low', 'medium', 'high', 'very_high'])

# %%
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
#            host_name  latitude  longitude  price  minimum_nights  \
# 0               John  40.64749  -73.97237    149               1
# 1           Jennifer  40.75362  -73.98377    225               1
# 2          Elisabeth  40.80902  -73.94190    150               3
# 3        LisaRoxanne  40.68514  -73.95976     89               1
# 4              Laura  40.79851  -73.94399     80              10
# ...              ...       ...        ...    ...             ...
# 48890        Sabrina  40.67853  -73.94995     70               2
# 48891        Marisol  40.70184  -73.93317     40               4
# 48892  Ilgar & Aysel  40.81475  -73.94867    115              10
# 48893            Taz  40.75751  -73.99112     55               1
# 48894     Christophe  40.76404  -73.98933     90               7
#
#        number_of_reviews last_review  ...  room_type_Entire home/apt  \
# 0                      9  2018-10-19  ...                      False
# 1                     45  2019-05-21  ...                       True
# 2                      0  2000-01-01  ...                      False
# 3                    270  2019-07-05  ...                       True
# 4                      9  2018-11-19  ...                       True
# ...                  ...         ...  ...                        ...
# 48890                  0  2000-01-01  ...                      False
# 48891                  0  2000-01-01  ...                      False
# 48892                  0  2000-01-01  ...                       True
# 48893                  0  2000-01-01  ...                      False
# 48894                  0  2000-01-01  ...                      False
#
#        room_type_Private room  room_type_Shared room  last_review_year  \
# 0                        True                  False              2018
# 1                       False                  False              2019
# 2                        True                  False              2000
# 3                       False                  False              2019
# 4                       False                  False              2018
# ...                       ...                    ...               ...
# 48890                    True                  False              2000
# 48891                    True                  False              2000
# 48892                   False                  False              2000
# 48893                   False                   True              2000
# 48894                    True                  False              2000
#
#        last_review_month  last_review_day  price_per_night  price_num_reviews  \
# 0                     10               19       149.000000               1341
# 1                      5               21       225.000000              10125
# 2                      1                1        50.000000                  0
# 3                      7                5        89.000000              24030
# 4                     11               19         8.000000                720
# ...                  ...              ...              ...                ...
# 48890                  1                1        35.000000                  0
# 48891                  1                1        10.000000                  0
# 48892                  1                1        11.500000                  0
# 48893                  1                1        55.000000                  0
# 48894                  1                1        12.857143                  0
#
#        price_availability  price_bin
# 0                0.407104       high
# 1                0.632022  very_high
# 2                0.409836       high
# 3                0.456410     medium
# 4               80.000000     medium
# ...                   ...        ...
# 48890            7.000000     medium
# 48891            1.081081        low
# 48892            4.107143       high
# 48893           18.333333     medium
# 48894            3.750000     medium
#
# [48895 rows x 249 columns]

# %% [markdown]
# ## Handling Outliers by Capping

# %%
df['price'].max()
# Out:
# 10000

# %%
df['price'] = np.clip(df['price'], df['price'].quantile(0.05), df['price'].quantile(0.95))
df['minimum_nights'] = np.clip(df['minimum_nights'], df['minimum_nights'].quantile(0.05), df['minimum_nights'].quantile(0.95))
df['number_of_reviews'] = np.clip(df['number_of_reviews'], df['number_of_reviews'].quantile(0.05), df['number_of_reviews'].quantile(0.95))

# %%
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
#            host_name  latitude  longitude  price  minimum_nights  \
# 0               John  40.64749  -73.97237    149               1
# 1           Jennifer  40.75362  -73.98377    225               1
# 2          Elisabeth  40.80902  -73.94190    150               3
# 3        LisaRoxanne  40.68514  -73.95976     89               1
# 4              Laura  40.79851  -73.94399     80              10
# ...              ...       ...        ...    ...             ...
# 48890        Sabrina  40.67853  -73.94995     70               2
# 48891        Marisol  40.70184  -73.93317     40               4
# 48892  Ilgar & Aysel  40.81475  -73.94867    115              10
# 48893            Taz  40.75751  -73.99112     55               1
# 48894     Christophe  40.76404  -73.98933     90               7
#
#        number_of_reviews last_review  ...  room_type_Entire home/apt  \
# 0                      9  2018-10-19  ...                      False
# 1                     45  2019-05-21  ...                       True
# 2                      0  2000-01-01  ...                      False
# 3                    114  2019-07-05  ...                       True
# 4                      9  2018-11-19  ...                       True
# ...                  ...         ...  ...                        ...
# 48890                  0  2000-01-01  ...                      False
# 48891                  0  2000-01-01  ...                      False
# 48892                  0  2000-01-01  ...                       True
# 48893                  0  2000-01-01  ...                      False
# 48894                  0  2000-01-01  ...                      False
#
#        room_type_Private room  room_type_Shared room  last_review_year  \
# 0                        True                  False              2018
# 1                       False                  False              2019
# 2                        True                  False              2000
# 3                       False                  False              2019
# 4                       False                  False              2018
# ...                       ...                    ...               ...
# 48890                    True                  False              2000
# 48891                    True                  False              2000
# 48892                   False                  False              2000
# 48893                   False                   True              2000
# 48894                    True                  False              2000
#
#        last_review_month  last_review_day  price_per_night  price_num_reviews  \
# 0                     10               19       149.000000               1341
# 1                      5               21       225.000000              10125
# 2                      1                1        50.000000                  0
# 3                      7                5        89.000000              24030
# 4                     11               19         8.000000                720
# ...                  ...              ...              ...                ...
# 48890                  1                1        35.000000                  0
# 48891                  1                1        10.000000                  0
# 48892                  1                1        11.500000                  0
# 48893                  1                1        55.000000                  0
# 48894                  1                1        12.857143                  0
#
#        price_availability  price_bin
# 0                0.407104       high
# 1                0.632022  very_high
# 2                0.409836       high
# 3                0.456410     medium
# 4               80.000000     medium
# ...                   ...        ...
# 48890            7.000000     medium
# 48891            1.081081        low
# 48892            4.107143       high
# 48893           18.333333     medium
# 48894            3.750000     medium
#
# [48895 rows x 249 columns]

# %%
df['price'].max()
# Out:
# 355
